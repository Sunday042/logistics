# %%
#Load libraries (np, pd, plt, sns, ...)
#Check Dataframes 
#Overview: print(df.info()), df.head()
#Clean-Up Columns/Variables
#Check for Null-Values 

#Check Data Types
#Decide what to do will Null-Values, e.g. use median to fill up

#Check for Outliers (df.drop, df.plot(subplots=True, kind=’box)
#convert order dates to dates
#Decide how to proceed with Outliers, e.g. drop
#Create new (enhanced) Variables/columns from existing Data [Engineering]

#Check Data for Patterns and Anomalies (Heatmap)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("~/neuefische/da-EDA_project_fork/data/muesli_raw_data_orders.csv", sep=";")
df2 = pd.read_csv("~/neuefische/da-EDA_project_fork/data/muesli_raw_data_study.csv", sep=";")
df3 = pd.read_csv("~/neuefische/da-EDA_project_fork/data/muesli_raw_data_process.csv", sep=";")
df4 = pd.read_csv("~/neuefische/da-EDA_project_fork/data/muesli_raw_data_campaign.csv", sep=";")

# %%
display(df1, df2, df3, df4)
# Out:
#             Order ID  Order Date Day of Week       Ship Mode Customer ID  \
# 0     CA-2019-121755   16/1/2019   Wednesday    Second Class    EH-13945
# 1     CA-2019-118255   11/3/2019      Monday     First Class    ON-18715
# 2     CA-2019-169194   20/6/2019    Thursday  Standard Class    LH-16900
# 3     CA-2019-111682   17/6/2019      Monday     First Class    TB-21055
# 4     CA-2018-135545  24/11/2018    Saturday  Standard Class    KM-16720
# ...              ...         ...         ...             ...         ...
# 9989  US-2019-115441   25/7/2019    Thursday    Second Class    SH-19975
# 9990  US-2018-129007   13/9/2018    Thursday     First Class    KD-16615
# 9991  CA-2018-132388  10/10/2018   Wednesday     First Class    KN-16390
# 9992  CA-2019-149272   15/3/2019      Friday  Standard Class    MY-18295
# 9993  CA-2020-121559    1/6/2020      Monday    Second Class    HW-14935
#
#           Customer Name Origin Channel Country/Region           City  \
# ...

# %%
display(df1["order_id"].nunique(),
df2["order_id"].nunique())
# Out:
# 5009
# 204

# %%
df1.columns = [c.lower() for c in df1.columns] #make everything lower case
df1.columns = [c.replace(' ', '_') for c in df1.columns] #replace spaces with underscores
df1.columns = [c.replace('/', '_') for c in df1.columns] #replace symbol with underscores
df1.columns = [c.replace('-', '_') for c in df1.columns] #replace symbol with underscores

# %%
df2.columns = [c.lower() for c in df2.columns] #make everything lower case
df2.columns = [c.replace(' ', '_') for c in df2.columns] #replace spaces with underscores
df2.columns = [c.replace('/', '_') for c in df2.columns] #replace symbol with underscores
df2.columns = [c.replace('-', '_') for c in df2.columns] #replace symbol with underscores

# %%
df3.columns = [c.lower() for c in df3.columns] #make everything lower case
df3.columns = [c.replace(' ', '_') for c in df3.columns] #replace spaces with underscores
df3.columns = [c.replace('/', '_') for c in df3.columns] #replace symbol with underscores
df3.columns = [c.replace('-', '_') for c in df3.columns] #replace symbol with underscores

# %%
df4.columns = [c.lower() for c in df4.columns] #make everything lower case
df4.columns = [c.replace(' ', '_') for c in df4.columns] #replace spaces with underscores
df4.columns = [c.replace('/', '_') for c in df4.columns] #replace symbol with underscores
df4.columns = [c.replace('-', '_') for c in df4.columns] #replace symbol with underscores

# %%
display(df1.columns, df2.columns, df3.columns, df4.columns)
# Out:
# Index(['order_id', 'order_date', 'day_of_week', 'ship_mode', 'customer_id',
#        'customer_name', 'origin_channel', 'country_region', 'city', 'state',
#        'postal_code', 'region', 'category', 'sub_category', 'product_id',
#        'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')
# Index(['order_id', 'ready_to_ship_date', 'pickup_date'], dtype='object')
# Index(['order_id', 'order_date', 'on_truck_scan_date', 'ship_mode'], dtype='object')
# Index(['order_id', 'arrival_scan_date', 'customer_name'], dtype='object')

# %%
display(df1.shape, #check for the sum of null values per variable/column: if not same as row number: do something about it
df2.shape,
df3.shape,
df4.shape)
# Out:
# (9994, 19)
# (290, 3)
# (5899, 4)
# (333, 3)

# %%
display(df1.notnull().sum(), #check for the sum of null values per variable/column: if not same as row number: do something about it
df2.notnull().sum(),
df3.notnull().sum(),
df4.notnull().sum())
# Out:
# order_id          9994
# order_date        9994
# day_of_week       9994
# ship_mode         9994
# customer_id       9994
# customer_name     9994
# origin_channel    9994
# country_region    9994
# city              9994
# state             9994
# postal_code       9983
# region            9994
# category          9994
# sub_category      9994
# product_id        9994
# sales             9994
# quantity          9994
# discount          9994
# profit            9994
# dtype: int64
# order_id              290
# ready_to_ship_date    290
# pickup_date           290
# dtype: int64
# order_id              5899
# order_date            5899
# on_truck_scan_date    5899
# ship_mode             5899
# dtype: int64
# order_id             333
# arrival_scan_date    333
# customer_name        333
# dtype: int64

# %% [markdown]
# #### Result
# * Postal Code in Orders does have Null Values
# * Procedure:
# Look at it
# Decide if we want to drop or fill it with other value

# %%
missing_postals = df1.query("postal_code.isnull() == True") #find the missing values in data set using query
missing_postals
# Out:
#             order_id order_date day_of_week       ship_mode customer_id  \
# 173   CA-2020-104066  5/12/2020    Saturday  Standard Class    QJ-19255
# 710   US-2019-165505  23/1/2019   Wednesday  Standard Class    CB-12535
# 1732  US-2020-127292  19/1/2020      Sunday  Standard Class    RM-19375
# 3408  US-2020-127292  19/1/2020      Sunday  Standard Class    RM-19375
# 3409  US-2020-127292  19/1/2020      Sunday  Standard Class    RM-19375
# 4279  US-2019-150140   6/4/2019    Saturday  Standard Class    VM-21685
# 4694  US-2020-127292  19/1/2020      Sunday  Standard Class    RM-19375
# 5490  US-2019-165505  23/1/2019   Wednesday  Standard Class    CB-12535
# 7802  US-2019-165505  23/1/2019   Wednesday  Standard Class    CB-12535
# 8415  CA-2018-117086  8/11/2018    Thursday  Standard Class    QJ-19255
# 9693  CA-2018-162887  7/11/2018   Wednesday    Second Class    SV-20785
#
#          customer_name origin_channel country_region        city    state  \
# ...

# %%
display(df1["profit"].mean(), df1["sales"].mean()) #Check if data is far away from mean and would change out overall findings significantly.
df1["profit"].std() #check standard deviation
# Out:
# 31.310733710226135
# 230.40238285971586
# 238.57278622905994

# %%
#We then found out they were all from the same city, just replace postal code with actual one

# %%
Burlingtons = df1.query("city == 'Burlington' and state == 'Vermont'") #Check for everybody from Burlinton, in the state of Vermont to see if there is a specific postal code missing, Result: No. 
Burlingtons
# Out:
#             order_id order_date day_of_week       ship_mode customer_id  \
# 173   CA-2020-104066  5/12/2020    Saturday  Standard Class    QJ-19255
# 710   US-2019-165505  23/1/2019   Wednesday  Standard Class    CB-12535
# 1732  US-2020-127292  19/1/2020      Sunday  Standard Class    RM-19375
# 3408  US-2020-127292  19/1/2020      Sunday  Standard Class    RM-19375
# 3409  US-2020-127292  19/1/2020      Sunday  Standard Class    RM-19375
# 4279  US-2019-150140   6/4/2019    Saturday  Standard Class    VM-21685
# 4694  US-2020-127292  19/1/2020      Sunday  Standard Class    RM-19375
# 5490  US-2019-165505  23/1/2019   Wednesday  Standard Class    CB-12535
# 7802  US-2019-165505  23/1/2019   Wednesday  Standard Class    CB-12535
# 8415  CA-2018-117086  8/11/2018    Thursday  Standard Class    QJ-19255
# 9693  CA-2018-162887  7/11/2018   Wednesday    Second Class    SV-20785
#
#          customer_name origin_channel country_region        city    state  \
# ...

# %%
df1["postal_code"].fillna(value = "05401", #Replace Postal Code with random postal code from the city of Burlington, Vermont
          inplace = True)

# %%
Burlingtons = df1.query("city == 'Burlington' and state == 'Vermont'") #Replacing Null Values worked
Burlingtons
# Out:
#             order_id order_date day_of_week       ship_mode customer_id  \
# 173   CA-2020-104066  5/12/2020    Saturday  Standard Class    QJ-19255
# 710   US-2019-165505  23/1/2019   Wednesday  Standard Class    CB-12535
# 1732  US-2020-127292  19/1/2020      Sunday  Standard Class    RM-19375
# 3408  US-2020-127292  19/1/2020      Sunday  Standard Class    RM-19375
# 3409  US-2020-127292  19/1/2020      Sunday  Standard Class    RM-19375
# 4279  US-2019-150140   6/4/2019    Saturday  Standard Class    VM-21685
# 4694  US-2020-127292  19/1/2020      Sunday  Standard Class    RM-19375
# 5490  US-2019-165505  23/1/2019   Wednesday  Standard Class    CB-12535
# 7802  US-2019-165505  23/1/2019   Wednesday  Standard Class    CB-12535
# 8415  CA-2018-117086  8/11/2018    Thursday  Standard Class    QJ-19255
# 9693  CA-2018-162887  7/11/2018   Wednesday    Second Class    SV-20785
#
#          customer_name origin_channel country_region        city    state  \
# ...

# %%
display(df1.isnull().sum(), #Everything non-null
df2.isnull().sum(),
df3.isnull().sum(),
df4.isnull().sum())
# Out:
# order_id          0
# order_date        0
# day_of_week       0
# ship_mode         0
# customer_id       0
# customer_name     0
# origin_channel    0
# country_region    0
# city              0
# state             0
# postal_code       0
# region            0
# category          0
# sub_category      0
# product_id        0
# sales             0
# quantity          0
# discount          0
# profit            0
# dtype: int64
# order_id              0
# ready_to_ship_date    0
# pickup_date           0
# dtype: int64
# order_id              0
# order_date            0
# on_truck_scan_date    0
# ship_mode             0
# dtype: int64
# order_id             0
# arrival_scan_date    0
# customer_name        0
# dtype: int64

# %%
display(df1.info(), df2.info(), df3.info(), df4.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        9994 non-null   object
#  1   order_date      9994 non-null   object
#  2   day_of_week     9994 non-null   object
#  3   ship_mode       9994 non-null   object
#  4   customer_id     9994 non-null   object
#  5   customer_name   9994 non-null   object
#  6   origin_channel  9994 non-null   object
#  7   country_region  9994 non-null   object
#  8   city            9994 non-null   object
#  9   state           9994 non-null   object
#  10  postal_code     9994 non-null   object
#  11  region          9994 non-null   object
#  12  category        9994 non-null   object
#  13  sub_category    9994 non-null   object
#  14  product_id      9994 non-null   object
#  15  sales           9994 non-null   float64
#  16  quantity        9994 non-null   int64
# ...

# %%
fig, axes = plt.subplots(4, 1, figsize=(30,10)) # check outliers in numerical variables, which only exist in df1 as the table above shows (data types)

#create chart in each subplot
sns.boxplot(x=df1["sales"], ax=axes[0])
sns.boxplot(x=df1["quantity"], ax=axes[1])
sns.boxplot(x=df1["discount"], ax=axes[2])
sns.boxplot(x=df1["profit"], ax=axes[3]);

# %%
# change the format to datetime for column 'order_date'
df12['order_date'] = pd.to_datetime(df12['order_date'], format = "%d/%m/%Y")
df22['arrival_scan_date'] = pd.to_datetime(df22['arrival_scan_date'], format = "%d/%m/%Y")
df32['order_date'] = pd.to_datetime(df32['order_date'], format = "%d/%m/%Y")
df32['on_truck_scan_date'] = pd.to_datetime(df32['on_truck_scan_date'], format = "%d/%m/%Y")
df42['ready_to_ship_date'] = pd.to_datetime(df42['ready_to_ship_date'], format = "%d/%m/%Y")
df42['pickup_date'] = pd.to_datetime(df42['pickup_date'], format = "%d/%m/%Y")
